# %% [markdown]
# <a href="https://colab.research.google.com/github/alok-9898/Scikit_learn/blob/main/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X, y = load_iris(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[-1.02536242, -0.18038282, -1.22235429, -1.31204989],
#        [-0.18588442, -0.66140367,  0.17568722,  0.11456119],
#        [-1.14528785,  0.06012761, -1.27827595, -1.31204989],
#        [ 2.21262418, -0.18038282,  1.29412042,  1.41148036],
#        [-0.30580985, -0.18038282,  0.17568722,  0.11456119],
#        [ 0.41374273, -0.42089324,  0.28753054,  0.11456119],
#        [ 0.17389187, -2.10446621,  0.67898216,  0.37394503],
#        [-1.14528785,  0.06012761, -1.27827595, -1.44174181],
#        [-0.06595899, -0.90191409,  0.17568722, -0.27451456],
#        [ 1.01336988, -0.18038282,  0.79082548,  1.41148036],
#        [-0.90543699,  1.74370057, -1.27827595, -1.18235798],
#        [ 2.21262418, -1.14242451,  1.7414937 ,  1.41148036],
#        [-0.18588442, -1.14242451, -0.15984275, -0.27451456],
#        [ 0.89344445, -0.18038282,  0.3434522 ,  0.24425311],
#        [-0.78551156,  2.46523184, -1.27827595, -1.44174181],
# ...

# %%
import numpy as np
X_train_scaled_np = (X_train - np.mean(X_train, axis=0)) / np.std(X_train,axis=0)
X_train_scaled_np

#This is the same calculation as done before by using the StandardScaler
# Out:
# array([[-1.02536242,  0.78165888, -1.27827595, -1.31204989],
#        [ 2.21262418, -0.66140367,  1.62965038,  1.02240461],
#        [ 0.65359359,  0.06012761,  0.95859046,  0.76302078],
#        [-1.02536242,  1.26267972, -1.33419761, -1.31204989],
#        [ 2.09269875, -0.18038282,  1.57372872,  1.15209653],
#        [-0.30580985, -0.18038282,  0.39937386,  0.37394503],
#        [ 2.45247503,  1.74370057,  1.4618854 ,  1.02240461],
#        [-0.42573527, -1.86395578,  0.11976556,  0.11456119],
#        [-0.90543699,  1.0221693 , -1.33419761, -1.18235798],
#        [ 1.85284789, -0.66140367,  1.29412042,  0.8927127 ],
#        [ 1.13329531, -0.18038282,  0.95859046,  1.15209653],
#        [ 0.65359359, -0.90191409,  0.84674714,  0.8927127 ],
#        [-1.14528785,  1.26267972, -1.33419761, -1.44174181],
#        [-0.06595899, -1.14242451,  0.11976556, -0.01513072],
#        [ 0.41374273, -0.66140367,  0.56713884,  0.76302078],
# ...
