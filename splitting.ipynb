# %% [markdown]
# <a href="https://colab.research.google.com/github/alok-9898/Scikit_learn/blob/main/scikit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
data = load_iris()

df = load_iris(as_frame=True).frame

X, y = data.data, data.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
X, y = load_iris(return_X_y=True)

# %%
train_test_split(X, y, test_size=0.2)  # 20% test and 80% train
# Out:
# [array([[6. , 3.4, 4.5, 1.6],
#         [4.8, 3. , 1.4, 0.1],
#         [5. , 3. , 1.6, 0.2],
#         [7.1, 3. , 5.9, 2.1],
#         [5.7, 2.8, 4.5, 1.3],
#         [7.2, 3.6, 6.1, 2.5],
#         [7.7, 3. , 6.1, 2.3],
#         [5.1, 2.5, 3. , 1.1],
#         [6.7, 3.3, 5.7, 2.1],
#         [5. , 2.3, 3.3, 1. ],
#         [5.1, 3.8, 1.5, 0.3],
#         [6.9, 3.2, 5.7, 2.3],
#         [6.3, 3.3, 6. , 2.5],
#         [6.5, 3. , 5.2, 2. ],
#         [5.7, 2.8, 4.1, 1.3],
#         [5.5, 4.2, 1.4, 0.2],
#         [6.1, 2.9, 4.7, 1.4],
#         [6.2, 2.2, 4.5, 1.5],
#         [5.1, 3.8, 1.6, 0.2],
#         [6.3, 2.8, 5.1, 1.5],
#         [5.4, 3.4, 1.5, 0.4],
#         [4.4, 2.9, 1.4, 0.2],
#         [6.1, 3. , 4.9, 1.8],
#         [5.8, 2.7, 3.9, 1.2],
#         [6.6, 3. , 4.4, 1.4],
#         [6.7, 3. , 5.2, 2.3],
#         [6.5, 3.2, 5.1, 2. ],
#         [4.6, 3.4, 1.4, 0.3],
#         [4.5, 2.3, 1.3, 0.3],
#         [6.7, 3.1, 5.6, 2.4],
#         [6. , 2.2, 4. , 1. ],
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#Visualizing training data
import numpy as np
import matplotlib.pyplot as plt

counts = np.bincount(y_train)
positions = np.arange(3)

plt.bar(positions,counts)
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x7c102eba1670>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
#Visualizing testing data
import numpy as np
import matplotlib.pyplot as plt

counts = np.bincount(y_test)
positions = np.arange(3)

plt.bar(positions,counts)
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x7c102f5bf3e0>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
#now managing the ratio of train and test data
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

for train_idx, test_idx in split.split(X, y):
  X_train, X_test = X[train_idx], X[test_idx]
  y_train, y_test = y[train_idx], y[test_idx]
