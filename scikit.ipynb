# %% [markdown]
# <a href="https://colab.research.google.com/github/alok-9898/Scikit_learn/blob/main/scikit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
data = load_iris()

df = load_iris(as_frame=True).frame

X, y = data.data, data.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
X, y = load_iris(return_X_y=True)

# %%
train_test_split(X, y, test_size=0.2)  # 20% test and 80% train
# Out:
# [array([[6. , 3.4, 4.5, 1.6],
#         [4.8, 3. , 1.4, 0.1],
#         [5. , 3. , 1.6, 0.2],
#         [7.1, 3. , 5.9, 2.1],
#         [5.7, 2.8, 4.5, 1.3],
#         [7.2, 3.6, 6.1, 2.5],
#         [7.7, 3. , 6.1, 2.3],
#         [5.1, 2.5, 3. , 1.1],
#         [6.7, 3.3, 5.7, 2.1],
#         [5. , 2.3, 3.3, 1. ],
#         [5.1, 3.8, 1.5, 0.3],
#         [6.9, 3.2, 5.7, 2.3],
#         [6.3, 3.3, 6. , 2.5],
#         [6.5, 3. , 5.2, 2. ],
#         [5.7, 2.8, 4.1, 1.3],
#         [5.5, 4.2, 1.4, 0.2],
#         [6.1, 2.9, 4.7, 1.4],
#         [6.2, 2.2, 4.5, 1.5],
#         [5.1, 3.8, 1.6, 0.2],
#         [6.3, 2.8, 5.1, 1.5],
#         [5.4, 3.4, 1.5, 0.4],
#         [4.4, 2.9, 1.4, 0.2],
#         [6.1, 3. , 4.9, 1.8],
#         [5.8, 2.7, 3.9, 1.2],
#         [6.6, 3. , 4.4, 1.4],
#         [6.7, 3. , 5.2, 2.3],
#         [6.5, 3.2, 5.1, 2. ],
#         [4.6, 3.4, 1.4, 0.3],
#         [4.5, 2.3, 1.3, 0.3],
#         [6.7, 3.1, 5.6, 2.4],
#         [6. , 2.2, 4. , 1. ],
#         [5.1, 3.4, 1.5, 0.2],
#         [6.3, 3.3, 4.7, 1.6],
#         [6.7, 3. , 5. , 1.7],
#         [5. , 3.2, 1.2, 0.2],
#         [5.1, 3.7, 1.5, 0.4],
#         [5.9, 3.2, 4.8, 1.8],
#         [6.8, 2.8, 4.8, 1.4],
#         [6.1, 2.8, 4. , 1.3],
#         [7.2, 3. , 5.8, 1.6],
#         [4.8, 3. , 1.4, 0.3],
#         [5.5, 2.4, 3.7, 1. ],
#         [4.9, 2.4, 3.3, 1. ],
#         [6.6, 2.9, 4.6, 1.3],
#         [5. , 3.5, 1.3, 0.3],
#         [6. , 3. , 4.8, 1.8],
#         [5.4, 3.9, 1.3, 0.4],
#         [5.9, 3. , 5.1, 1.8],
#         [5. , 3.5, 1.6, 0.6],
#         [6.7, 3.1, 4.4, 1.4],
#         [4.6, 3.2, 1.4, 0.2],
#         [6.2, 3.4, 5.4, 2.3],
#         [5.2, 2.7, 3.9, 1.4],
#         [5.1, 3.3, 1.7, 0.5],
#         [6.4, 2.8, 5.6, 2.2],
#         [4.9, 3.1, 1.5, 0.1],
#         [5.1, 3.5, 1.4, 0.2],
#         [5.8, 4. , 1.2, 0.2],
#         [5.7, 3. , 4.2, 1.2],
#         [6.7, 3.3, 5.7, 2.5],
#         [5.4, 3.9, 1.7, 0.4],
#         [5.1, 3.5, 1.4, 0.3],
#         [5.2, 3.4, 1.4, 0.2],
#         [5.6, 2.9, 3.6, 1.3],
#         [7.6, 3. , 6.6, 2.1],
#         [5.6, 2.7, 4.2, 1.3],
#         [6.3, 2.5, 5. , 1.9],
#         [6.9, 3.1, 4.9, 1.5],
#         [6.8, 3.2, 5.9, 2.3],
#         [5.7, 4.4, 1.5, 0.4],
#         [5.7, 2.5, 5. , 2. ],
#         [5.1, 3.8, 1.9, 0.4],
#         [7.3, 2.9, 6.3, 1.8],
#         [5.9, 3. , 4.2, 1.5],
#         [5.8, 2.7, 5.1, 1.9],
#         [4.7, 3.2, 1.6, 0.2],
#         [6.2, 2.8, 4.8, 1.8],
#         [5.4, 3.4, 1.7, 0.2],
#         [4.6, 3.6, 1. , 0.2],
#         [6.3, 2.9, 5.6, 1.8],
#         [7. , 3.2, 4.7, 1.4],
#         [6.4, 3.2, 5.3, 2.3],
#         [6.3, 3.4, 5.6, 2.4],
#         [6.1, 2.6, 5.6, 1.4],
#         [4.8, 3.1, 1.6, 0.2],
#         [5.6, 3. , 4.5, 1.5],
#         [7.7, 2.6, 6.9, 2.3],
#         [7.9, 3.8, 6.4, 2. ],
#         [5. , 3.4, 1.6, 0.4],
#         [6.5, 3. , 5.8, 2.2],
#         [6.1, 3. , 4.6, 1.4],
#         [5.5, 2.5, 4. , 1.3],
#         [4.9, 3.6, 1.4, 0.1],
#         [4.9, 3. , 1.4, 0.2],
#         [6.3, 2.5, 4.9, 1.5],
#         [4.3, 3. , 1.1, 0.1],
#         [4.8, 3.4, 1.9, 0.2],
#         [4.6, 3.1, 1.5, 0.2],
#         [6.2, 2.9, 4.3, 1.3],
#         [6.8, 3. , 5.5, 2.1],
#         [6.7, 3.1, 4.7, 1.5],
#         [7.7, 3.8, 6.7, 2.2],
#         [5.8, 2.7, 4.1, 1. ],
#         [4.8, 3.4, 1.6, 0.2],
#         [5.5, 2.3, 4. , 1.3],
#         [6. , 2.7, 5.1, 1.6],
#         [5.6, 2.8, 4.9, 2. ],
#         [5. , 3.6, 1.4, 0.2],
#         [5.5, 2.4, 3.8, 1.1],
#         [6.4, 2.8, 5.6, 2.1],
#         [5.8, 2.8, 5.1, 2.4],
#         [7.7, 2.8, 6.7, 2. ],
#         [6.5, 3. , 5.5, 1.8],
#         [6.4, 3.2, 4.5, 1.5],
#         [4.7, 3.2, 1.3, 0.2],
#         [6.5, 2.8, 4.6, 1.5],
#         [5.3, 3.7, 1.5, 0.2],
#         [5.4, 3. , 4.5, 1.5],
#         [6.7, 2.5, 5.8, 1.8],
#         [5. , 3.4, 1.5, 0.2]]),
#  array([[6.9, 3.1, 5.4, 2.1],
#         [6. , 2.9, 4.5, 1.5],
#         [7.4, 2.8, 6.1, 1.9],
#         [6.1, 2.8, 4.7, 1.2],
#         [5.8, 2.7, 5.1, 1.9],
#         [5. , 3.3, 1.4, 0.2],
#         [6.9, 3.1, 5.1, 2.3],
#         [4.4, 3. , 1.3, 0.2],
#         [4.9, 2.5, 4.5, 1.7],
#         [6.3, 2.7, 4.9, 1.8],
#         [6.4, 2.7, 5.3, 1.9],
#         [5.2, 3.5, 1.5, 0.2],
#         [5.5, 2.6, 4.4, 1.2],
#         [5.7, 2.6, 3.5, 1. ],
#         [5.6, 2.5, 3.9, 1.1],
#         [5.7, 2.9, 4.2, 1.3],
#         [6. , 2.2, 5. , 1.5],
#         [5. , 2. , 3.5, 1. ],
#         [5.7, 3.8, 1.7, 0.3],
#         [6.4, 3.1, 5.5, 1.8],
#         [7.2, 3.2, 6. , 1.8],
#         [4.4, 3.2, 1.3, 0.2],
#         [5.4, 3.7, 1.5, 0.2],
#         [6.4, 2.9, 4.3, 1.3],
#         [6.3, 2.3, 4.4, 1.3],
#         [5.6, 3. , 4.1, 1.3],
#         [5.5, 3.5, 1.3, 0.2],
#         [5.2, 4.1, 1.5, 0.1],
#         [5.8, 2.6, 4. , 1.2],
#         [4.9, 3.1, 1.5, 0.2]]),
#  array([1, 0, 0, 2, 1, 2, 2, 1, 2, 1, 0, 2, 2, 2, 1, 0, 1, 1, 0, 2, 0, 0,
#         2, 1, 1, 2, 2, 0, 0, 2, 1, 0, 1, 1, 0, 0, 1, 1, 1, 2, 0, 1, 1, 1,
#         0, 2, 0, 2, 0, 1, 0, 2, 1, 0, 2, 0, 0, 0, 1, 2, 0, 0, 0, 1, 2, 1,
#         2, 1, 2, 0, 2, 0, 2, 1, 2, 0, 2, 0, 0, 2, 1, 2, 2, 2, 0, 1, 2, 2,
#         0, 2, 1, 1, 0, 0, 1, 0, 0, 0, 1, 2, 1, 2, 1, 0, 1, 1, 2, 0, 1, 2,
#         2, 2, 2, 1, 0, 1, 0, 1, 2, 0]),
#  array([2, 1, 2, 1, 2, 0, 2, 0, 2, 2, 2, 0, 1, 1, 1, 1, 2, 1, 0, 2, 2, 0,
#         0, 1, 1, 1, 0, 0, 1, 0])]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#Visualizing training data
import numpy as np
import matplotlib.pyplot as plt

counts = np.bincount(y_train)
positions = np.arange(3)

plt.bar(positions,counts)
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x7c1032baa270>,
#   <matplotlib.axis.XTick at 0x7c1032c340e0>,
#   <matplotlib.axis.XTick at 0x7c1032b97980>],
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
#Visualizing testing data
import numpy as np
import matplotlib.pyplot as plt

counts = np.bincount(y_test)
positions = np.arange(3)

plt.bar(positions,counts)
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x7c1031ec8f80>,
#   <matplotlib.axis.XTick at 0x7c103319c830>,
#   <matplotlib.axis.XTick at 0x7c1031eb8e00>],
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])
